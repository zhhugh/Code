# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def findBottomLeftValue(self, root: Optional[TreeNode]) -> int:
        if not root:
            return -1
        global pre_d
        global res
        global max_d
        def dfs(root, d):
            global pre_d
            global res
            global max_d
            if not root:
                return
            if d > pre_d:
                if not root.left and not root.right and max_d < d:
                    res = root.val
                    max_d = d
                    return
            dfs(root.left, d + 1)
            dfs(root.right, d + 1)
        pre_d = 0
        res = None
        max_d = 0
        dfs(root, 1)
        return res

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def hasPathSum(self, root: Optional[TreeNode], targetSum: int) -> bool:
        if root is None:
            return False
        
        return self._hasPathSum(root, targetSum)

    def _hasPathSum(self, root, targetSum):
        if not root.left and not root.right:
            return root.val == targetSum
        has = False
        if root.left:
            has |= self._hasPathSum(root.left, targetSum - root.val)
        if root.right:
            has |= self._hasPathSum(root.right, targetSum - root.val)
        return has

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def buildTree(self, inorder: List[int], postorder: List[int]) -> Optional[TreeNode]:
        if not postorder:
            return
        root_val = postorder[-1]
        root = TreeNode(root_val)
        idx = 0
        for i in range(len(inorder)):
            if root_val == inorder[i]:
                idx = i
                break
        left_inorder, right_inorder = inorder[0: idx], inorder[idx + 1:]
        left_postorder, right_postorder = postorder[0:idx], postorder[idx:-1]
        root.left = self.buildTree(left_inorder, left_postorder)
        root.right = self.buildTree(right_inorder, right_postorder)
        return root
